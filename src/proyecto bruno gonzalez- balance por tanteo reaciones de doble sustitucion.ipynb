# %%
# Datos personales
#nobre del autor BRUNO GUILLERMO GONZALEZ ORTEGA

#Especificaciones técnicas: (breve descripción de lo que realiza).
#Se diseño interfas grafica con cinco pestañas
# en la primera se  incorporaron  cuatro listas desplegables de las cuales se optiene  cationes y aniones  para generarar compuestos
#use colocaron botones para unaves que son selectionados los iones  se forman lor reativos los priductos  se llaman los numeros de 
#oxidacion se colocantambiren los subindices de reaccion y los iones de reaccion para el balanceo 
# 3n las otras ventqnas se calcularan masas atomicas de cada compuestos  balanceo de moles y calculo de reativo limitante y gramos de productos y la nomenclatura



# Código 


from tkinter import *
from tkinter import messagebox
import tkinter as tk
from tkinter import ttk
from tkinter.ttk import Combobox
import csv

########## REACTIVOS
def seleccionar_ion1():
    ion1_seleccionado = combobox_iones1.get()
    ion2_seleccionado = combobox_iones2.get()
    ion3_seleccionado = combobox_iones3.get()
    ion4_seleccionado = combobox_iones4.get()
    etiqueta_ion1.config(text= ion1_seleccionado )
    etiqueta_ion2.config(text="("+  ion2_seleccionado+")"  )
    etiqueta_ion9.config(text= "+" )
    etiqueta_ion3.config(text= ion3_seleccionado )
    etiqueta_ion4.config(text="("+  ion4_seleccionado+")"  )
    etiqueta_ion21.config(text= ion1_seleccionado )
    etiqueta_ion22.config(text= ion2_seleccionado )
    etiqueta_ion23.config(text= ion3_seleccionado )
    etiqueta_ion24.config(text= ion4_seleccionado )
    etiqueta_ion25.config(text= ion1_seleccionado )
    etiqueta_ion26.config(text= ion1_seleccionado )
    etiqueta_ion27.config(text= ion1_seleccionado )
    etiqueta_ion28.config(text= ion1_seleccionado )
    
    
    
    
   ######## PRODUCTOS    
def seleccionar_ion3():
    ion1_seleccionado = combobox_iones1.get()
    ion2_seleccionado = combobox_iones2.get()
    ion3_seleccionado = combobox_iones3.get()
    ion4_seleccionado = combobox_iones4.get()
    etiqueta_ion10.config(text= " ->" )
    etiqueta_ion11.config(text= ion1_seleccionado )
    etiqueta_ion12.config(text="("+  ion4_seleccionado+")"  )
    etiqueta_ion13.config(text= "+" )
    etiqueta_ion14.config(text= ion3_seleccionado )
    etiqueta_ion15.config(text="("+  ion2_seleccionado+")"  )
    
    
 ######## PLANTEAMIENTO DE BALANCEO   
    
def seleccionar_ion2():
    ion5_seleccionado = combobox_iones1.get()
    ion6_seleccionado = combobox_iones2.get()
    ion7_seleccionado = combobox_iones3.get()
    ion8_seleccionado = combobox_iones4.get()
    etiqueta_ion5.config(text=" -"+ ion5_seleccionado+" -" )
    etiqueta_ion6.config(text=" -"+ ion6_seleccionado+" -"  )
    etiqueta_ion7.config(text=" -"+ ion7_seleccionado+" -" )
    etiqueta_ion8.config(text=" -"+ ion8_seleccionado+" -"  )
   
    
    
    


# Función para  definir  numero de oxidacion 
def mostrar_oxidacion():
    elemento_seleccionado = var_elemento1.get()
    carga = elementos.get(elemento_seleccionado)
    cargaion1.config(text=f"{carga}")
    cargaion5.config(text=f"{carga}")
    
    elemento_seleccionado2 = var_elemento2.get()
    carga = elementos1.get(elemento_seleccionado2)
    cargaion2.config(text=f" {carga}")
    cargaion8.config(text=f" {carga}")
    
    elemento_seleccionado3 = var_elemento3.get()
    carga = elementos.get(elemento_seleccionado3)
    cargaion3.config(text=f" {carga}")
    cargaion7.config(text=f" {carga}")
    
    elemento_seleccionado4 = var_elemento4.get()
    carga = elementos1.get(elemento_seleccionado4)
    cargaion4.config(text=f"{carga}")
    cargaion6.config(text=f"{carga}")
    
   
 # Función para  definir  sub indices
def subindices():
    elemento_seleccionado = var_elemento1.get()
    carga = elementos.get(elemento_seleccionado)
    cargaion11.config(text=f"{carga}")
    cargaion15.config(text=f"{carga}")
    
    elemento_seleccionado2 = var_elemento2.get()
    carga = elementos1.get(elemento_seleccionado2)
    cargaion12.config(text=f" {carga*-1}")
    cargaion18.config(text=f" {carga*-1}")
    
    elemento_seleccionado3 = var_elemento3.get()
    carga = elementos.get(elemento_seleccionado3)
    cargaion13.config(text=f" {carga}")
    cargaion17.config(text=f" {carga}")
    
    elemento_seleccionado4 = var_elemento4.get()
    carga = elementos1.get(elemento_seleccionado4)
    cargaion14.config(text=f"{carga*-1}")
    cargaion16.config(text=f"{carga*-1}")
    
    
    # Función para  BALANCE
def BALANCE():
    elemento_seleccionado = var_elemento1.get()
    carga = elementos.get(elemento_seleccionado)
    BALANCE11.config(text=f"{carga}")
    BALANCE15.config(text=f"{carga}")
    
    elemento_seleccionado2 = var_elemento2.get()
    carga = elementos1.get(elemento_seleccionado2)
    BALANCE12.config(text=f" {carga*-1}")
    BALANCE18.config(text=f" {carga*-1}")
    
    elemento_seleccionado3 = var_elemento3.get()
    carga = elementos.get(elemento_seleccionado3)
    BALANCE13.config(text=f" {carga}")
    BALANCE17.config(text=f" {carga}")
    
    elemento_seleccionado4 = var_elemento4.get()
    carga = elementos1.get(elemento_seleccionado4)
    BALANCE14.config(text=f"{carga*-1}")
    BALANCE16.config(text=f"{carga*-1}")
    
    
    
    
     # Función para  definir  NEUTROS
def nombre():
    elemento_seleccionado = var_elemento1.get()
    carga = elementos.get(elemento_seleccionado)
    nombre = elementos.get(elemento_seleccionado)
    peso1.config(text=f"{carga}")
    peso5.config(text=f"{carga}")

    
      
    elemento_seleccionado2 = var_elemento2.get()
    carga = elementos1.get(elemento_seleccionado2)
    peso2.config(text=f" {carga*-1}")
    peso6.config(text=f" {carga*-1}")
    
    elemento_seleccionado = var_elemento3.get()
    carga = elementos.get(elemento_seleccionado)
    nombre = elementos.get(elemento_seleccionado)
    peso3.config(text=f"{carga}")
    peso7.config(text=f"{carga}")

      
    elemento_seleccionado2 = var_elemento4.get()
    carga = elementos1.get(elemento_seleccionado2)
    peso4.config(text=f" {carga*-1}")
    peso8.config(text=f" {carga*-1}")
     
    
    
    
    
    
    
    
############################################### LLAMANDO DATOS
    
################## CARGANDO   NUMEROS DE OXIDACION
    
    # Cargar los elementos   cationes
    
elementos = {}
with open('cation1.csv', 'r') as archivo_csv:
    lector_csv = csv.DictReader(archivo_csv)
    for fila in lector_csv:
        elemento = fila['elemento']
        CARGA= int(fila['carga'])
        elementos[elemento] = CARGA
        #NOMBRE= int(fila['nombre'])
        #elementos[elemento] = NOMBRE
        
      


 # Cargar los elementos   aniones
    
elementos1= {}
with open('anion1.csv', 'r') as archivo_csv:
    lector_csv = csv.DictReader(archivo_csv)
    for fila in lector_csv:
        elemento = fila['elemento']
        CARGA = int(fila['carga'])
        elementos1[elemento] = CARGA

      
        
   
      



    
   





        
 ################################################################################ VENTANA       
        
        
      # Crear la ventana
ventana = tk.Tk()
ventana.title("balanceo reacciones qumicas")
ventana.geometry("1300x800")
ventana.iconbitmap("CU.ico")  
        
######################################################## pestañas        
 #INCLUIMOS PANEL PARA LAS PESTAÑAS.
nb = ttk.Notebook(ventana)
nb.pack(fill='both',expand='yes')

#CREAMOS PESTAÑAS
p1 = ttk.Frame(nb)
p2 = ttk.Frame(nb)
p3 = ttk.Frame(nb)
p4 = ttk.Frame(nb)
p5 = ttk.Frame(nb)
p6 = ttk.Frame(nb)
       
        
        #######################################creando variables  para guardar datos       


# Crear una variable para cobo1
var_elemento1 = StringVar(ventana)
var_elemento1.set("")  # Establecer un valor predeterminado

# Crear una variable para combo2
var_elemento2 = StringVar(ventana)
var_elemento2.set("")  # Establecer un valor predeterminado


# Crear una variable para cobo1
var_elemento3 = StringVar(ventana)
var_elemento3.set("")  # Establecer un valor predeterminado

# Crear una variable para combo2
var_elemento4 = StringVar(ventana)
var_elemento4.set("")  # Establecer un valor predeterminado


################ creando listas deplegables 
######################combo 1
# Crear el widget de lista desplegable 1
etiqueta_ion1 = ttk.Label(p1, text="cation-1")
etiqueta_ion1.place(x=125,y=40)


# Crear un ComboBox con los elementos de la tabla periódica
combobox_iones1 = Combobox(p1, textvariable=var_elemento1, values=list(elementos.keys()))
combobox_iones1.pack()
combobox_iones1.place(x=120,y=60)

######################combo 2
# Crear el widget de lista desplegable 2
etiqueta_ion2 = ttk.Label(p1, text="anion-1")
etiqueta_ion2.place(x=325,y=40)


# Crear un ComboBox con los elementos de la tabla periódica
combobox_iones2 = Combobox(p1, textvariable=var_elemento2, values=list(elementos1.keys()))
combobox_iones2.pack()
combobox_iones2.place(x=320,y=60)


############################################### segundo compuesto

######################combo 3
# Crear el widget de lista desplegable 3
etiqueta_ion3 = ttk.Label(p1, text="cation-2")
etiqueta_ion3.place(x=525,y=40)


# Crear un ComboBox con los elementos de la tabla periódica
combobox_iones3 = Combobox(p1, textvariable=var_elemento3, values=list(elementos.keys()))
combobox_iones3.pack()
combobox_iones3.place(x=520,y=60)

######################combo 4
# Crear el widget de lista desplegable 4
etiqueta_ion4 = ttk.Label(p1, text="anion-2")
etiqueta_ion4.place(x=725,y=40)


# Crear un ComboBox con los elementos de la tabla periódica
combobox_iones4 = Combobox(p1, textvariable=var_elemento4, values=list(elementos1.keys()))
combobox_iones4.pack()
combobox_iones4.place(x=720,y=60)



#####################################################################################################3

# Crear el botón de selección
boton_seleccionar = ttk.Button(p1, text="Seleccionar", command=seleccionar_ion1)
boton_seleccionar.pack()
boton_seleccionar.place(x=1150,y=55)


# Crear el botón de PRODUCTOS
boton_seleccionar3 = ttk.Button(p1, text="PRODUCTOS", command=seleccionar_ion3)
boton_seleccionar3.pack()
boton_seleccionar3.place(x=1150,y=100)


# Crear un botón para mostra numeros de oxidacion
boton_oxidacion = ttk.Button(p1, text="#  DE OXIDACION", command=mostrar_oxidacion)
boton_oxidacion.pack()
boton_oxidacion.place(x=1150,y=150)

# Crear un botón para mostra subindices
boton_subindices = ttk.Button(p1, text="subindices", command=subindices)
boton_subindices.pack()
boton_subindices.place(x=1150,y=200)

# Crear el botón de selección
boton_seleccionar2 = ttk.Button(p1, text="BALANCEO", command=seleccionar_ion2)
boton_seleccionar2.pack()
boton_seleccionar2.place(x=1150,y=250)

# Crear el botón de selección
boton_seleccionar2 = ttk.Button(p1, text="EN BALANCE", command=BALANCE)
boton_seleccionar2.pack()
boton_seleccionar2.place(x=1150,y=300)


# Crear el botón escribe nombr
boton_seleccionar2 = ttk.Button(p2, text="masas", command=nombre)
boton_seleccionar2.pack()
boton_seleccionar2.place(x=1150,y=250)






######################

######## Crear la etiqueta de reaccion
################ COMPUESTOS REACTIBOS     #######
#####     ETIQUETA ION 1 #############
etiqueta_ion1 = ttk.Label(p1, text="",font=("Verdana",30))
etiqueta_ion1.pack()
etiqueta_ion1.place(x=50,y=200)


#####     ETIQUETA ION 2 #############
etiqueta_ion2 = ttk.Label(p1, text="",font=("Verdana",30))
etiqueta_ion2.pack()
etiqueta_ion2.place(x=120,y=200)
 

#####     ETIQUETA  + #############
etiqueta_ion9 = ttk.Label(p1, text="",font=("Verdana",30))
etiqueta_ion9.pack()
etiqueta_ion9.place(x=270,y=200)


#####     ETIQUETA ION 3 #############
etiqueta_ion3 = ttk.Label(p1, text="",font=("Verdana",30))
etiqueta_ion3.pack()
etiqueta_ion3.place(x=310,y=200)
 

#####     ETIQUETA ION 4 #############
etiqueta_ion4 = ttk.Label(p1, text="",font=("Verdana",30))
etiqueta_ion4.pack()
etiqueta_ion4.place(x=380,y=200)


################ COMPUESTOS PRODUCTOS     #######

#####     ETIQUETA FLECHA #############
etiqueta_ion10 = ttk.Label(p1, text="",font=("Verdana",30))
etiqueta_ion10.pack()
etiqueta_ion10.place(x=530,y=200)



#####     ETIQUETA ION 11 #############
etiqueta_ion11 = ttk.Label(p1, text="",font=("Verdana",30))
etiqueta_ion11.pack()
etiqueta_ion11.place(x=650,y=200)


#####     ETIQUETA ION 12 #############
etiqueta_ion12 = ttk.Label(p1, text="",font=("Verdana",30))
etiqueta_ion12.pack()
etiqueta_ion12.place(x=720,y=200)
 

#####     ETIQUETA  + #############
etiqueta_ion13 = ttk.Label(p1, text="",font=("Verdana",30))
etiqueta_ion13.pack()
etiqueta_ion13.place(x=880,y=200)


#####     ETIQUETA ION 14 #############
etiqueta_ion14 = ttk.Label(p1, text="",font=("Verdana",30))
etiqueta_ion14.pack()
etiqueta_ion14.place(x=910,y=200)


#####     ETIQUETA ION 15 #############
etiqueta_ion15 = ttk.Label(p1, text="",font=("Verdana",30))
etiqueta_ion15.pack()
etiqueta_ion15.place(x=980,y=200)

 

# ########################Crear la etiqueta de iones de reaccion

#####     ETIQUETA ION 1 #############
etiqueta_ion5 = ttk.Label(p1, text="",font=("Verdana",30))
etiqueta_ion5.pack()
etiqueta_ion5.place(x=520,y=300)
 

#####     ETIQUETA ION 2 #############
etiqueta_ion6 = ttk.Label(p1, text="",font=("Verdana",30))
etiqueta_ion6.pack()
etiqueta_ion6.place(x=520,y=400)


#####     ETIQUETA ION 3 #############
etiqueta_ion7 = ttk.Label(p1, text="",font=("Verdana",30))
etiqueta_ion7.pack()
etiqueta_ion7.place(x=520,y=500)
 

#####     ETIQUETA ION 4 #############
etiqueta_ion8 = ttk.Label(p1, text="",font=("Verdana",30))
etiqueta_ion8.pack()
etiqueta_ion8.place(x=520,y=600)
 

# Crear una etiqueta para mostrar el resultado
etiqueta_resultado = Label(p1, text="")
etiqueta_resultado.pack()




######################################### numeros de oxidacion

# numero de oxidacion ion 1
cargaion1 = Label(p1, text="",fg="green",font=("Verdana",15))
cargaion1.pack()
cargaion1.place(x=80,y=180)

# numero de oxidacion ion 2
cargaion2 = Label(p1, text="",fg="red",font=("Verdana",15))
cargaion2.pack()
cargaion2.place(x=190,y=180)


# numero de oxidacion ion 3
cargaion3 = Label(p1, text="",fg="green",font=("Verdana",15))
cargaion3.pack()
cargaion3.place(x=340,y=180)

# numero de oxidacion ion 4
cargaion4 = Label(p1, text="",fg="red",font=("Verdana",15))
cargaion4.pack()
cargaion4.place(x=440,y=180)

###################################################### oxidacionproductos
# numero de oxidacion ion 2
cargaion5 = Label(p1, text="",fg="green",font=("Verdana",15))
cargaion5.pack()
cargaion5.place(x=670,y=180)


# numero de oxidacion ion 6
cargaion6 = Label(p1, text="",fg="red",font=("Verdana",15))
cargaion6.pack()
cargaion6.place(x=770,y=180)


# numero de oxidacion ion 2
cargaion7 = Label(p1, text="",fg="green",font=("Verdana",15))
cargaion7.pack()
cargaion7.place(x=915,y=180)


# numero de oxidacion ion 6
cargaion8 = Label(p1, text="",fg="red",font=("Verdana",15))
cargaion8.pack()
cargaion8.place(x=1040,y=180)

##################################################### sub indices


# numero de oxidacion ion 11
cargaion11 = Label(p1, text="",fg="green yellow",font=("Verdana",15))
cargaion11.pack()
cargaion11.place(x=205,y=250)


# numero de oxidacion ion 12
cargaion12 = Label(p1, text="",fg="magenta",font=("Verdana",15))
cargaion12.pack()
cargaion12.place(x=75,y=250)


# numero de oxidacion ion 13
cargaion13 = Label(p1, text="",fg="green",font=("Verdana",15))
cargaion13.pack()
cargaion13.place(x=1050,y=250)


# numero de oxidacion ion 14
cargaion14 = Label(p1, text="",fg="gold",font=("Verdana",15))
cargaion14.pack()
cargaion14.place(x=345,y=250)




# numero de oxidacion ion 15
cargaion15 = Label(p1, text="",fg="green",font=("Verdana",15))
cargaion15.pack()
cargaion15.place(x=790,y=250)


# numero de oxidacion ion 16
cargaion16 = Label(p1, text="",fg="yellow",font=("Verdana",15))
cargaion16.pack()
cargaion16.place(x=670,y=250)

# numero de oxidacion ion 173
cargaion17 = Label(p1, text="",fg="green",font=("Verdana",15))
cargaion17.pack()
cargaion17.place(x=445,y=250)



# numero de oxidacion ion 18
cargaion18 = Label(p1, text="",fg="magenta",font=("Verdana",15))
cargaion18.pack()
cargaion18.place(x=940,y=250)




##################################################### BALANCE


# numero de oxidacion ion 11
BALANCE11 = Label(p1, text="",font=("Verdana",25))
BALANCE11.pack()
BALANCE11.place(x=505,y=405)


# numero de oxidacion ion 12
BALANCE12 = Label(p1, text="",font=("Verdana",25))
BALANCE12.pack()
BALANCE12.place(x=505,y=300)


# numero de oxidacion ion 13
BALANCE13 = Label(p1, text="",font=("Verdana",25))
BALANCE13.pack()
BALANCE13.place(x=505,y=600)


# numero de oxidacion ion 14
BALANCE14 = Label(p1, text="",font=("Verdana",25))
BALANCE14.pack()
BALANCE14.place(x=505,y=500)



# numero de oxidacion ion 15
BALANCE15 = Label(p1, text="",font=("Verdana",25))
BALANCE15.pack()
BALANCE15.place(x=700,y=600)




# numero de oxidacion ion 16
BALANCE16 = Label(p1, text="",font=("Verdana",25))
BALANCE16.pack()
BALANCE16.place(x=700,y=300)

# numero de oxidacion ion 173
BALANCE17 = Label(p1, text="",font=("Verdana",25))
BALANCE17.pack()
BALANCE17.place(x=700,y=405)

# numero de oxidacion ion 18
BALANCE18 = Label(p1, text="",font=("Verdana",25))
BALANCE18.pack()
BALANCE18.place(x=700,y=500)






######################################################### p2 ####################################################

####################################COMPUESTO 1

etiqueta_compuesto1 = Label(p2, text=" COMPUESTO 1 ",font=("Verdana",15))
etiqueta_compuesto1.pack()
etiqueta_compuesto1.place(x=70,y=20)

# numero de oxidacion ion 18
etiqueta_ion21 = Label(p2, text="",fg="red",font=("Verdana",15))
etiqueta_ion21.pack()
etiqueta_ion21.place(x=70,y=60)

# numero de oxidacion ion 15
peso2 = Label(p2, text="",fg="gold",font=("Verdana",15))
peso2.pack()
peso2.place(x=130,y=60)

# numero de oxidacion ion 18
etiqueta_ion22 = Label(p2, text="",fg="red",font=("Verdana",15))
etiqueta_ion22.pack()
etiqueta_ion22.place(x=70,y=100)
 
# numero de oxidacion ion 18
peso1 = Label(p2, text="",fg="green",font=("Verdana",15))
peso1.pack()
peso1.place(x=130,y=100)

####################################COMPUESTO 2

etiqueta_compuesto1 = Label(p2, text=" COMPUESTO 2 ",font=("Verdana",15))
etiqueta_compuesto1.pack()
etiqueta_compuesto1.place(x=70,y=150)

# numero de oxidacion ion 18
etiqueta_ion23 = Label(p2, text="",fg="red",font=("Verdana",15))
etiqueta_ion23.pack()
etiqueta_ion23.place(x=70,y=180)

# numero de oxidacion ion 15
peso4 = Label(p2, text="",fg="gold",font=("Verdana",15))
peso4.pack()
peso4.place(x=130,y=180)


# numero de oxidacion ion 18
etiqueta_ion24 = Label(p2, text="",fg="red",font=("Verdana",15))
etiqueta_ion24.pack()
etiqueta_ion24.place(x=70,y=220)


# numero de oxidacion ion 18
peso3 = Label(p2, text="",fg="green",font=("Verdana",15))
peso3.pack()
peso3.place(x=130,y=220)











#####     ETIQUETA creditos #############





#####     ETIQUETA DE AYUDA #############
etiqueta_ayuda = ttk.Label(p5, text=" por el momento no podemos ayudarte",font=("Verdana",40))
etiqueta_ayuda.pack()
etiqueta_ayuda.place(x=100,y=100)


etiqueta_ayuda2 = ttk.Label(p5, text="  estamos en construccion ",font=("Verdana",40))
etiqueta_ayuda2.pack()
etiqueta_ayuda2.place(x=100,y=300)


etiqueta_ayuda3 = ttk.Label(p5, text=" trabajando en ello para mejorar  el sistema ",font=("Verdana",25))
etiqueta_ayuda3.pack()
etiqueta_ayuda3.place(x=100,y=450)






######################################################### p6 ####################################################



#####     ETIQUETA creditos #############
etiqueta_cred = ttk.Label(p6, text=" Diseñado por   ",font=("Verdana",40))
etiqueta_cred.pack()
etiqueta_cred.place(x=450,y=100)


etiqueta_creb = ttk.Label(p6, text="  Mtro. Bruno Guillermo González Ortega ",font=("Verdana",40))
etiqueta_creb.pack()
etiqueta_creb.place(x=100,y=300)


etiqueta_crec = ttk.Label(p6, text=" contacto iqbggo@gmail.com ",font=("Verdana",25))
etiqueta_crec.pack()
etiqueta_crec.place(x=450,y=450)




#AGREGAMOS PESTAÑAS CREADAS
nb.add(p1,text='planteando la reaccion')
nb.add(p2,text='calculando pesos moleculares')
nb.add(p3,text='opteniendo gramos de la reaccion ')
nb.add(p4,text='nomenclatura')
nb.add(p5,text='AYUDA')
nb.add(p6,text='creditos')






# Ejecutar la ventana principal
ventana.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "d:\Users\yoda\anaconda3\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\yoda\AppData\Local\Temp\ipykernel_8892\1220882900.py", line 38, in seleccionar_ion1
#     etiqueta_ion25.config(text= ion1_seleccionado )
# NameError: name 'etiqueta_ion25' is not defined
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "d:\Users\yoda\anaconda3\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\yoda\AppData\Local\Temp\ipykernel_8892\1220882900.py", line 38, in seleccionar_ion1
#     etiqueta_ion25.config(text= ion1_seleccionado )
# NameError: name 'etiqueta_ion25' is not defined
